# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_parquet('data\processed_windspeed.parquet')

print(df.head())
# Out:
#   abréviation_station horodatage_référence  \
# 0                 BOU     01.02.2004 00:00
# 1                 BOU     01.02.2004 00:10
# 2                 BOU     01.02.2004 00:20
# 3                 BOU     01.02.2004 00:30
# 4                 BOU     01.02.2004 00:40
#
#    température_air_2m_valeur_instantanée  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    température_refroidissement_éolien_valeur_instantanée  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    humidité_relative_air_2m_valeur_instantanée  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    point_de_rosée_2m_valeur_instantanée  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#    pression_vapeur_2m_valeur_instantanée  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    pression_barométrique_qfe_valeur_instantanée  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    pression_niveau_mer_standard_qnh_valeur_instantanée  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    pression_niveau_mer_réelle_qff_valeur_instantanée  rafale_1s_maximum_10min  \
# 0                                                NaN                      2.8
# 1                                                NaN                      3.0
# 2                                                NaN                      4.0
# 3                                                NaN                      5.2
# 4                                                NaN                      4.7
#
#    vitesse_vent_vectorielle_moyenne_10min  \
# 0                                     1.9
# 1                                     2.2
# 2                                     2.4
# 3                                     3.7
# 4                                     3.2
#
#    vitesse_vent_scalaire_moyenne_10min  direction_du_vent_moyenne_10min  \
# 0                                  1.9                            149.0
# 1                                  2.3                            144.0
# 2                                  2.5                            140.0
# 3                                  3.8                            137.0
# 4                                  3.3                            148.0
#
#    vitesse_vent_moyenne_10min_kmh  rafale_3s_maximum_10min  \
# 0                             6.8                      NaN
# 1                             7.9                      NaN
# 2                             8.6                      NaN
# 3                            13.3                      NaN
# 4                            11.5                      NaN
#
#    rafale_1s_maximum_kmh  rafale_3s_maximum_kmh  précipitations_somme_10min
# 0                   10.1                    NaN                         0.0
# 1                   10.8                    NaN                         0.0
# 2                   14.4                    NaN                         0.0
# 3                   18.7                    NaN                         0.0
# 4                   16.9                    NaN                         0.0
